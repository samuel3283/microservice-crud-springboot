# %% [markdown]
# # Microservice CRUD Spring Boot en Google Colab
#
# Este notebook descarga, compila y ejecuta el proyecto Spring Boot desde GitHub.

# %%
# !git clone https://github.com/samuel3283/microservice-crud-springboot.git
# %cd microservice-crud-springboot

# %%
# !apt-get update -qq

# %%
# !apt-get install -y openjdk-8-jdk maven

# %%
# !java -version
# !mvn -version

# %%
# !find . -name pom.xml

# %%
# !mvn clean package -DskipTests

# %%
# !ls -la target

# %%
# !java -jar target/*.jar
